# %% [markdown]
# # Doanh thu

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 import seaborn as sns
#       5 from sklearn.model_selection import train_test_split
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
#Đọc file
csv_file_path = r'D:\DATN\DATN---Phantom-Data\Data dự án\data\cleaned\superstore_cleaned.csv'
df = pd.read_csv(csv_file_path)

print("\nDataFrame from CSV file:")
print(df)

#In ra 5 hàng đầu tiên của DataFrame df để khám phá dữ liệu.
print("\nFirst 5 rows of the DataFrame:")
print(df.head())

#Sử dụng phương thức info() để hiển thị thông tin về cấu trúc của DataFrame df, bao gồm số lượng hàng và cột, và kiểu dữ liệu của các cột.
print("\nDataFrame info:")
print(df.info())
# Out:
# DataFrame from CSV file:
#               category         city    country customer_id      customer_name  \
# 0      Office Supplies  Wagga Wagga  Australia   JH-159851        Joseph Holt
# 1      Office Supplies    Stockholm     Sweden   EM-141402       Eugene Moren
# 2      Office Supplies  Constantine    Algeria   TB-112801    Toby Braunhardt
# 3      Office Supplies  Wagga Wagga  Australia   JH-159851        Joseph Holt
# 4      Office Supplies     Budapest    Hungary     AT-7352      Annie Thurman
# ...                ...          ...        ...         ...                ...
# 51247  Office Supplies         Caen     France   RD-194802        Rick Duston
# 51248       Technology        Jilin      China   MG-176951      Maureen Gnade
# 51249        Furniture        Konya     Turkey   VD-116702  Valerie Dominguez
# 51250       Technology          Ufa     Russia    PB-91051       Peter Bühler
# 51251  Office Supplies   Vijayawada      India   BS-113651       Bill Shonely
#
# ...

# %% [markdown]
# # Doanh thu theo năm

# %%
sales_year = df.groupby("order_year")["sales"].sum()

plt.figure(figsize=(8,5))
plt.plot(sales_year.index,
         sales_year.values,
         marker='o',
         linewidth=3)

plt.title("Revenue by Year")
plt.xlabel("Year")
plt.ylabel("Sales")

plt.grid(True)
plt.show()

# %% [markdown]
# # Top 10 quốc gia doanh thu cao nhất

# %%
country_sales = (
    df.groupby("country")["sales"]
      .sum()
      .sort_values(ascending=False)
      .head(10)
)

plt.figure(figsize=(10,5))
country_sales.plot(kind="bar")

plt.title("Top 10 Countries by Sales")
plt.ylabel("Sales")
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# # Doanh thu theo Category

# %%
category_sales = df.groupby("category")["sales"].sum()

plt.figure(figsize=(6,5))

category_sales.plot(
    kind="bar",
    color=["skyblue","orange","green"]
)

plt.title("Sales by Category")
plt.ylabel("Sales")

plt.show()
